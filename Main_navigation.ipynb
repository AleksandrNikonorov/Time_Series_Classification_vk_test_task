# %%
from my_models_pipline import ModelsPipline
from catboost import CatBoostClassifier
from sklearn.ensemble import RandomForestClassifier
import create_dataset_functions as f
import numpy as np
import pandas as pd
from collections import defaultdict
import pickle


class MainNavigation:
    def __init__(self, models_grid = None, param_grids = None, agg_func = None):
        if models_grid is not None:
            self.models_grid = models_grid
        else:
            self.models_grid = {'CatBoost': lambda: CatBoostClassifier(),
                                # 'RandomForest' : lambda: RandomForestClassifier()
                                }
        if param_grids is not None:
            self.param_grids = param_grids
        else:
            catboost_param_grid = {
                'depth': [4, 6],
                'iterations': [100],
                }

            # catboost_param_grid = {
            #     'depth': [4, 6],
            #     'learning_rate': [0.05],
            #     'iterations': [1000, 1500],
            #     'early_stopping_rounds': [50, 100]
            #     }


            # random_forest_param_grid = {
            #     'n_estimators': [100],
            #     'max_depth': [10, 20],
            #     'min_samples_split': [5]
            #     }

            self.param_grids = {
                            'CatBoost': catboost_param_grid,
                            # 'RandomForest': random_forest_param_grid
                            }
                
        if agg_func is not None:
            self.features = agg_func
        else: 
            self.features = [
                ("Range", lambda x: x.max() - x.min()),  # Размах
                ('Q1', lambda x: np.percentile(x, 25) if len(x) != 0 else np.nan),  # Первый квартиль (Q1)
                ("Q3", lambda x: np.percentile(x, 75) if len(x) != 0 else np.nan),  # Третий квартиль (Q3)
                ("IQR", lambda x: (np.percentile(x, 75) - np.percentile(x, 25)) if len(x) != 0 else np.nan),  # Межквартильный размах (IQR)
                ("Autocorr", lambda x: x.autocorr() if len(x) > 1 else np.nan),  # Автокорреляция
                ("Skewness", lambda x: x.skew() if len(x) != 0 else np.nan),  # Скос
                ("Kurtosis", lambda x: x.kurt() if len(x) != 0 else np.nan),  # Куртозис
                ("Mean", lambda x: x.mean() if len(x) != 0 else np.nan),  # Среднее значение
                ("Median", lambda x: x.median() if len(x) != 0 else np.nan),  # Медиана
                ("Std", lambda x: x.std() if len(x) != 0 else np.nan),  # Стандартное отклонение
                ("Min", lambda x: x.min() if len(x) != 0 else np.nan),  # Минимум
                ("Max", lambda x: x.max() if len(x) != 0 else np.nan)  # Максимум
                ]
        self.grid_data = defaultdict()
        self.trained_model_name = None

    def create_dataset(self, data_type = 'rolling', train_path = 'train.parquet', test_path = 'train.parquet'):
        if data_type == 'rolling':
            id_convert_ts_train, id_convert_ts_test = f.convert_rolling_time_series(train_path=train_path, 
                                                                                    test_path= test_path)
        else:
            id_convert_ts_train, id_convert_ts_test = f.convert_time_series(train_path=train_path, 
                                                                            test_path= test_path)
        
        train_data = f.create_dataset(self.features, id_ts= id_convert_ts_train)
        train_data_file = f'intervals_dataframe{len(self.grid_data)}.csv'
        train_data_name = f'{data_type}_Intervals_12Stats_{len(self.grid_data)}'
        train_data.to_csv(train_data_file)
        self.grid_data[train_data_name] = train_data_file

        test_data = f.create_dataset(self.features, id_ts= id_convert_ts_test)
        test_data_file = 'test_data.csv'
        test_data.to_csv(test_data_file)
        self.grid_data['Test'] = train_data_file


    def run_model_selection(self):
        if len(self.grid_data) == 0:
            self.grid_data = {
                'rolling_Intervals_12Stats_0': 'intervals_dataframe0.csv',
                'Test': 'test_data.csv'
            }
        model_selector = ModelsPipline(
                                    models = self.models_grid, 
                                    param_grids= self.param_grids,
                                    dataframes_path = self.grid_data)
        model_selector.run()
        results = pd.DataFrame(model_selector.results)
        print(results)
        results = results.sort_values(by='score')
        self.trained_model_name = model_selector.final_model_fit_save(results.iloc[0,:0])
        return results
        
    def get_submission(self):
        with open(self.trained_model_name, 'rb') as file:
            model = pickle.load(file)
        submission = model.predict(self.grid_data['Test'])
        submission.to_csv('submissions.csv')
        return submission

# %%
nagivation = MainNavigation()
# nagivation.create_dataset()
nagivation.run_model_selection()
nagivation.get_submission()
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]
# intervals_dataframe0.csv
# Learning rate set to 0.47469
# 0:	learn: 0.5622458	total: 166ms	remaining: 16.5s
# 1:	learn: 0.5169527	total: 180ms	remaining: 8.82s
# 2:	learn: 0.4954448	total: 192ms	remaining: 6.22s
# 3:	learn: 0.4825047	total: 204ms	remaining: 4.89s
# 4:	learn: 0.4726146	total: 217ms	remaining: 4.12s
# 5:	learn: 0.4659951	total: 234ms	remaining: 3.66s
# 6:	learn: 0.4582833	total: 249ms	remaining: 3.3s
# 7:	learn: 0.4522430	total: 263ms	remaining: 3.03s
# 8:	learn: 0.4458535	total: 277ms	remaining: 2.8s
# 9:	learn: 0.4400648	total: 289ms	remaining: 2.6s
# 10:	learn: 0.4363297	total: 301ms	remaining: 2.43s
# 11:	learn: 0.4319404	total: 313ms	remaining: 2.29s
# 12:	learn: 0.4294170	total: 325ms	remaining: 2.17s
# 13:	learn: 0.4250636	total: 337ms	remaining: 2.07s
# 14:	learn: 0.4230035	total: 349ms	remaining: 1.98s
# 15:	learn: 0.4211167	total: 362ms	remaining: 1.9s
# 16:	learn: 0.4191905	total: 376ms	remaining: 1.84s
# 17:	learn: 0.4174596	total: 389ms	remaining: 1.77s
# 18:	learn: 0.4148404	total: 404ms	remaining: 1.72s
# 19:	learn: 0.4137474	total: 416ms	remaining: 1.66s
# 20:	learn: 0.4115685	total: 429ms	remaining: 1.61s
# 21:	learn: 0.4103962	total: 442ms	remaining: 1.57s
# 22:	learn: 0.4085960	total: 455ms	remaining: 1.52s
# 23:	learn: 0.4067380	total: 466ms	remaining: 1.48s
# 24:	learn: 0.4053979	total: 477ms	remaining: 1.43s
# 25:	learn: 0.4034194	total: 490ms	remaining: 1.39s
# 26:	learn: 0.4009552	total: 503ms	remaining: 1.36s
# 27:	learn: 0.3992368	total: 515ms	remaining: 1.32s
# 28:	learn: 0.3968477	total: 527ms	remaining: 1.29s
# 29:	learn: 0.3950110	total: 540ms	remaining: 1.26s
# 30:	learn: 0.3932107	total: 554ms	remaining: 1.23s
# 31:	learn: 0.3919703	total: 565ms	remaining: 1.2s
# 32:	learn: 0.3908830	total: 578ms	remaining: 1.17s
# 33:	learn: 0.3892097	total: 591ms	remaining: 1.15s
# 34:	learn: 0.3879802	total: 604ms	remaining: 1.12s
# 35:	learn: 0.3864932	total: 617ms	remaining: 1.1s
# 36:	learn: 0.3854059	total: 628ms	remaining: 1.07s
# 37:	learn: 0.3842633	total: 642ms	remaining: 1.05s
# 38:	learn: 0.3831886	total: 655ms	remaining: 1.02s
# 39:	learn: 0.3819410	total: 668ms	remaining: 1s
# 40:	learn: 0.3811494	total: 681ms	remaining: 980ms
# 41:	learn: 0.3803930	total: 693ms	remaining: 957ms
# 42:	learn: 0.3790199	total: 706ms	remaining: 936ms
# 43:	learn: 0.3780005	total: 719ms	remaining: 915ms
# 44:	learn: 0.3768122	total: 731ms	remaining: 894ms
# 45:	learn: 0.3759378	total: 743ms	remaining: 872ms
# 46:	learn: 0.3753907	total: 755ms	remaining: 852ms
# 47:	learn: 0.3745364	total: 768ms	remaining: 833ms
# 48:	learn: 0.3736144	total: 779ms	remaining: 811ms
# 49:	learn: 0.3724026	total: 795ms	remaining: 795ms
# 50:	learn: 0.3717807	total: 807ms	remaining: 775ms
# 51:	learn: 0.3711135	total: 820ms	remaining: 757ms
# 52:	learn: 0.3705424	total: 834ms	remaining: 739ms
# 53:	learn: 0.3696980	total: 863ms	remaining: 735ms
# 54:	learn: 0.3687605	total: 885ms	remaining: 724ms
# 55:	learn: 0.3677495	total: 898ms	remaining: 705ms
# 56:	learn: 0.3670500	total: 909ms	remaining: 685ms
# 57:	learn: 0.3664389	total: 923ms	remaining: 668ms
# 58:	learn: 0.3658895	total: 935ms	remaining: 650ms
# 59:	learn: 0.3651663	total: 948ms	remaining: 632ms
# 60:	learn: 0.3643603	total: 960ms	remaining: 613ms
# 61:	learn: 0.3637935	total: 971ms	remaining: 595ms
# 62:	learn: 0.3630713	total: 985ms	remaining: 579ms
# 63:	learn: 0.3624495	total: 996ms	remaining: 560ms
# 64:	learn: 0.3617645	total: 1.01s	remaining: 543ms
# 65:	learn: 0.3611575	total: 1.02s	remaining: 526ms
# 66:	learn: 0.3607861	total: 1.03s	remaining: 510ms
# 67:	learn: 0.3602222	total: 1.05s	remaining: 493ms
# 68:	learn: 0.3595804	total: 1.06s	remaining: 477ms
# 69:	learn: 0.3589893	total: 1.07s	remaining: 461ms
# 70:	learn: 0.3582502	total: 1.09s	remaining: 445ms
# 71:	learn: 0.3576841	total: 1.1s	remaining: 429ms
# 72:	learn: 0.3572680	total: 1.11s	remaining: 412ms
# 73:	learn: 0.3566377	total: 1.13s	remaining: 396ms
# 74:	learn: 0.3559673	total: 1.14s	remaining: 380ms
# 75:	learn: 0.3556036	total: 1.15s	remaining: 363ms
# 76:	learn: 0.3551860	total: 1.16s	remaining: 347ms
# 77:	learn: 0.3547181	total: 1.17s	remaining: 331ms
# 78:	learn: 0.3541393	total: 1.19s	remaining: 316ms
# 79:	learn: 0.3535232	total: 1.2s	remaining: 300ms
# 80:	learn: 0.3530251	total: 1.23s	remaining: 290ms
# 81:	learn: 0.3524179	total: 1.25s	remaining: 274ms
# 82:	learn: 0.3518792	total: 1.26s	remaining: 258ms
# 83:	learn: 0.3514459	total: 1.27s	remaining: 243ms
# 84:	learn: 0.3509766	total: 1.29s	remaining: 227ms
# 85:	learn: 0.3505269	total: 1.3s	remaining: 212ms
# 86:	learn: 0.3501385	total: 1.31s	remaining: 196ms
# 87:	learn: 0.3495874	total: 1.32s	remaining: 180ms
# 88:	learn: 0.3490342	total: 1.33s	remaining: 165ms
# 89:	learn: 0.3485952	total: 1.35s	remaining: 150ms
# 90:	learn: 0.3481459	total: 1.36s	remaining: 135ms
# 91:	learn: 0.3477329	total: 1.37s	remaining: 120ms
# 92:	learn: 0.3473104	total: 1.39s	remaining: 104ms
# 93:	learn: 0.3466747	total: 1.4s	remaining: 89.5ms
# 94:	learn: 0.3460946	total: 1.42s	remaining: 74.5ms
# 95:	learn: 0.3457633	total: 1.43s	remaining: 59.5ms
# 96:	learn: 0.3454040	total: 1.44s	remaining: 44.6ms
# 97:	learn: 0.3449754	total: 1.45s	remaining: 29.6ms
# 98:	learn: 0.3445304	total: 1.47s	remaining: 14.8ms
# 99:	learn: 0.3439541	total: 1.48s	remaining: 0us
# Learning rate set to 0.47469
# 0:	learn: 0.5622458	total: 13.1ms	remaining: 1.29s
# 1:	learn: 0.5169527	total: 28.8ms	remaining: 1.41s
# 2:	learn: 0.4954448	total: 42.5ms	remaining: 1.38s
# 3:	learn: 0.4825047	total: 54.7ms	remaining: 1.31s
# 4:	learn: 0.4726146	total: 68.2ms	remaining: 1.29s
# 5:	learn: 0.4659951	total: 80.8ms	remaining: 1.26s
# 6:	learn: 0.4582833	total: 92.4ms	remaining: 1.23s
# 7:	learn: 0.4522430	total: 105ms	remaining: 1.21s
# 8:	learn: 0.4458535	total: 118ms	remaining: 1.2s
# 9:	learn: 0.4400648	total: 130ms	remaining: 1.17s
# 10:	learn: 0.4363297	total: 144ms	remaining: 1.16s
# 11:	learn: 0.4319404	total: 157ms	remaining: 1.15s
# 12:	learn: 0.4294170	total: 169ms	remaining: 1.13s
# 13:	learn: 0.4250636	total: 181ms	remaining: 1.11s
# 14:	learn: 0.4230035	total: 193ms	remaining: 1.09s
# 15:	learn: 0.4211167	total: 207ms	remaining: 1.09s
# 16:	learn: 0.4191905	total: 220ms	remaining: 1.07s
# 17:	learn: 0.4174596	total: 234ms	remaining: 1.06s
# 18:	learn: 0.4148404	total: 246ms	remaining: 1.05s
# 19:	learn: 0.4137474	total: 259ms	remaining: 1.04s
# 20:	learn: 0.4115685	total: 271ms	remaining: 1.02s
# 21:	learn: 0.4103962	total: 284ms	remaining: 1.01s
# 22:	learn: 0.4085960	total: 297ms	remaining: 996ms
# 23:	learn: 0.4067380	total: 309ms	remaining: 978ms
# 24:	learn: 0.4053979	total: 321ms	remaining: 962ms
# 25:	learn: 0.4034194	total: 349ms	remaining: 993ms
# 26:	learn: 0.4009552	total: 362ms	remaining: 980ms
# 27:	learn: 0.3992368	total: 374ms	remaining: 961ms
# 28:	learn: 0.3968477	total: 387ms	remaining: 947ms
# 29:	learn: 0.3950110	total: 399ms	remaining: 932ms
# 30:	learn: 0.3932107	total: 412ms	remaining: 916ms
# 31:	learn: 0.3919703	total: 423ms	remaining: 900ms
# 32:	learn: 0.3908830	total: 438ms	remaining: 889ms
# 33:	learn: 0.3892097	total: 456ms	remaining: 885ms
# 34:	learn: 0.3879802	total: 469ms	remaining: 872ms
# 35:	learn: 0.3864932	total: 482ms	remaining: 856ms
# 36:	learn: 0.3854059	total: 493ms	remaining: 839ms
# 37:	learn: 0.3842633	total: 506ms	remaining: 825ms
# 38:	learn: 0.3831886	total: 518ms	remaining: 810ms
# 39:	learn: 0.3819410	total: 531ms	remaining: 796ms
# 40:	learn: 0.3811494	total: 543ms	remaining: 782ms
# 41:	learn: 0.3803930	total: 556ms	remaining: 768ms
# 42:	learn: 0.3790199	total: 570ms	remaining: 756ms
# 43:	learn: 0.3780005	total: 582ms	remaining: 741ms
# 44:	learn: 0.3768122	total: 594ms	remaining: 726ms
# 45:	learn: 0.3759378	total: 606ms	remaining: 712ms
# 46:	learn: 0.3753907	total: 618ms	remaining: 697ms
# 47:	learn: 0.3745364	total: 632ms	remaining: 685ms
# 48:	learn: 0.3736144	total: 644ms	remaining: 670ms
# 49:	learn: 0.3724026	total: 659ms	remaining: 659ms
# 50:	learn: 0.3717807	total: 672ms	remaining: 645ms
# 51:	learn: 0.3711135	total: 685ms	remaining: 632ms
# 52:	learn: 0.3705424	total: 699ms	remaining: 619ms
# 53:	learn: 0.3696980	total: 713ms	remaining: 607ms
# 54:	learn: 0.3687605	total: 728ms	remaining: 595ms
# 55:	learn: 0.3677495	total: 743ms	remaining: 583ms
# 56:	learn: 0.3670500	total: 759ms	remaining: 572ms
# 57:	learn: 0.3664389	total: 776ms	remaining: 562ms
# 58:	learn: 0.3658895	total: 790ms	remaining: 549ms
# 59:	learn: 0.3651663	total: 805ms	remaining: 537ms
# 60:	learn: 0.3643603	total: 822ms	remaining: 526ms
# 61:	learn: 0.3637935	total: 836ms	remaining: 512ms
# 62:	learn: 0.3630713	total: 853ms	remaining: 501ms
# 63:	learn: 0.3624495	total: 868ms	remaining: 488ms
# 64:	learn: 0.3617645	total: 884ms	remaining: 476ms
# 65:	learn: 0.3611575	total: 899ms	remaining: 463ms
# 66:	learn: 0.3607861	total: 914ms	remaining: 450ms
# 67:	learn: 0.3602222	total: 929ms	remaining: 437ms
# 68:	learn: 0.3595804	total: 945ms	remaining: 425ms
# 69:	learn: 0.3589893	total: 960ms	remaining: 411ms
# 70:	learn: 0.3582502	total: 974ms	remaining: 398ms
# 71:	learn: 0.3576841	total: 990ms	remaining: 385ms
# 72:	learn: 0.3572680	total: 1s	remaining: 371ms
# 73:	learn: 0.3566377	total: 1.02s	remaining: 357ms
# 74:	learn: 0.3559673	total: 1.03s	remaining: 344ms
# 75:	learn: 0.3556036	total: 1.05s	remaining: 331ms
# 76:	learn: 0.3551860	total: 1.06s	remaining: 318ms
# 77:	learn: 0.3547181	total: 1.08s	remaining: 304ms
# 78:	learn: 0.3541393	total: 1.09s	remaining: 291ms
# 79:	learn: 0.3535232	total: 1.11s	remaining: 277ms
# 80:	learn: 0.3530251	total: 1.12s	remaining: 263ms
# 81:	learn: 0.3524179	total: 1.13s	remaining: 249ms
# 82:	learn: 0.3518792	total: 1.15s	remaining: 236ms
# 83:	learn: 0.3514459	total: 1.17s	remaining: 222ms
# 84:	learn: 0.3509766	total: 1.18s	remaining: 208ms
# 85:	learn: 0.3505269	total: 1.19s	remaining: 194ms
# 86:	learn: 0.3501385	total: 1.2s	remaining: 180ms
# 87:	learn: 0.3495874	total: 1.22s	remaining: 166ms
# 88:	learn: 0.3490342	total: 1.23s	remaining: 152ms
# 89:	learn: 0.3485952	total: 1.24s	remaining: 138ms
# 90:	learn: 0.3481459	total: 1.26s	remaining: 125ms
# 91:	learn: 0.3477329	total: 1.27s	remaining: 111ms
# 92:	learn: 0.3473104	total: 1.29s	remaining: 97.1ms
# 93:	learn: 0.3466747	total: 1.31s	remaining: 83.4ms
# 94:	learn: 0.3460946	total: 1.32s	remaining: 69.7ms
# 95:	learn: 0.3457633	total: 1.34s	remaining: 55.8ms
# 96:	learn: 0.3454040	total: 1.35s	remaining: 41.8ms
# 97:	learn: 0.3449754	total: 1.36s	remaining: 27.8ms
# 98:	learn: 0.3445304	total: 1.38s	remaining: 13.9ms
# 99:	learn: 0.3439541	total: 1.4s	remaining: 0us
# 100%|██████████| 1/1 [00:20<00:00, 20.21s/it]
#  50%|█████     | 1/2 [00:21<00:21, 21.34s/it]
# test_data.csv
# Learning rate set to 0.47469
# 0:	learn: 0.5580566	total: 14.3ms	remaining: 1.42s
# 1:	learn: 0.5162546	total: 27.6ms	remaining: 1.35s
# 2:	learn: 0.4993501	total: 39.9ms	remaining: 1.29s
# 3:	learn: 0.4863152	total: 52.3ms	remaining: 1.25s
# 4:	learn: 0.4748169	total: 65.1ms	remaining: 1.24s
# 5:	learn: 0.4652014	total: 78.9ms	remaining: 1.24s
# 6:	learn: 0.4578807	total: 90.9ms	remaining: 1.21s
# 7:	learn: 0.4532094	total: 102ms	remaining: 1.17s
# 8:	learn: 0.4475100	total: 115ms	remaining: 1.16s
# 9:	learn: 0.4430933	total: 131ms	remaining: 1.18s
# 10:	learn: 0.4394084	total: 143ms	remaining: 1.16s
# 11:	learn: 0.4348377	total: 157ms	remaining: 1.15s
# 12:	learn: 0.4317669	total: 171ms	remaining: 1.15s
# 13:	learn: 0.4295894	total: 184ms	remaining: 1.13s
# 14:	learn: 0.4271994	total: 195ms	remaining: 1.11s
# 15:	learn: 0.4245471	total: 209ms	remaining: 1.09s
# 16:	learn: 0.4219604	total: 221ms	remaining: 1.08s
# 17:	learn: 0.4200853	total: 239ms	remaining: 1.09s
# 18:	learn: 0.4172277	total: 253ms	remaining: 1.08s
# 19:	learn: 0.4156444	total: 266ms	remaining: 1.06s
# 20:	learn: 0.4135486	total: 281ms	remaining: 1.06s
# 21:	learn: 0.4114133	total: 294ms	remaining: 1.04s
# 22:	learn: 0.4090640	total: 306ms	remaining: 1.02s
# 23:	learn: 0.4067701	total: 318ms	remaining: 1.01s
# 24:	learn: 0.4044240	total: 330ms	remaining: 991ms
# 25:	learn: 0.4025322	total: 342ms	remaining: 975ms
# 26:	learn: 0.4011738	total: 354ms	remaining: 958ms
# 27:	learn: 0.3995628	total: 369ms	remaining: 948ms
# 28:	learn: 0.3980922	total: 381ms	remaining: 933ms
# 29:	learn: 0.3971353	total: 393ms	remaining: 917ms
# 30:	learn: 0.3956607	total: 405ms	remaining: 902ms
# 31:	learn: 0.3942476	total: 417ms	remaining: 887ms
# 32:	learn: 0.3925964	total: 431ms	remaining: 875ms
# 33:	learn: 0.3911231	total: 446ms	remaining: 867ms
# 34:	learn: 0.3893825	total: 461ms	remaining: 857ms
# 35:	learn: 0.3883060	total: 475ms	remaining: 845ms
# 36:	learn: 0.3865384	total: 490ms	remaining: 834ms
# 37:	learn: 0.3852117	total: 502ms	remaining: 819ms
# 38:	learn: 0.3839865	total: 514ms	remaining: 804ms
# 39:	learn: 0.3828237	total: 526ms	remaining: 789ms
# 40:	learn: 0.3816943	total: 542ms	remaining: 780ms
# 41:	learn: 0.3809705	total: 557ms	remaining: 769ms
# 42:	learn: 0.3797785	total: 569ms	remaining: 754ms
# 43:	learn: 0.3788070	total: 580ms	remaining: 739ms
# 44:	learn: 0.3779919	total: 593ms	remaining: 725ms
# 45:	learn: 0.3772251	total: 605ms	remaining: 711ms
# 46:	learn: 0.3763814	total: 618ms	remaining: 697ms
# 47:	learn: 0.3754455	total: 629ms	remaining: 682ms
# 48:	learn: 0.3746952	total: 643ms	remaining: 669ms
# 49:	learn: 0.3738126	total: 658ms	remaining: 658ms
# 50:	learn: 0.3730794	total: 672ms	remaining: 645ms
# 51:	learn: 0.3721742	total: 684ms	remaining: 631ms
# 52:	learn: 0.3713241	total: 696ms	remaining: 617ms
# 53:	learn: 0.3706325	total: 708ms	remaining: 603ms
# 54:	learn: 0.3698790	total: 721ms	remaining: 590ms
# 55:	learn: 0.3690889	total: 733ms	remaining: 576ms
# 56:	learn: 0.3682871	total: 744ms	remaining: 561ms
# 57:	learn: 0.3674325	total: 757ms	remaining: 548ms
# 58:	learn: 0.3667071	total: 770ms	remaining: 535ms
# 59:	learn: 0.3660467	total: 782ms	remaining: 521ms
# 60:	learn: 0.3654953	total: 792ms	remaining: 507ms
# 61:	learn: 0.3649104	total: 821ms	remaining: 503ms
# 62:	learn: 0.3641742	total: 834ms	remaining: 490ms
# 63:	learn: 0.3634022	total: 844ms	remaining: 475ms
# 64:	learn: 0.3628808	total: 857ms	remaining: 461ms
# 65:	learn: 0.3623886	total: 870ms	remaining: 448ms
# 66:	learn: 0.3618823	total: 882ms	remaining: 434ms
# 67:	learn: 0.3614114	total: 897ms	remaining: 422ms
# 68:	learn: 0.3605963	total: 908ms	remaining: 408ms
# 69:	learn: 0.3600988	total: 922ms	remaining: 395ms
# 70:	learn: 0.3596423	total: 934ms	remaining: 382ms
# 71:	learn: 0.3591155	total: 947ms	remaining: 368ms
# 72:	learn: 0.3587145	total: 961ms	remaining: 355ms
# 73:	learn: 0.3583223	total: 971ms	remaining: 341ms
# 74:	learn: 0.3579319	total: 984ms	remaining: 328ms
# 75:	learn: 0.3573079	total: 997ms	remaining: 315ms
# 76:	learn: 0.3566910	total: 1.01s	remaining: 302ms
# 77:	learn: 0.3561684	total: 1.02s	remaining: 288ms
# 78:	learn: 0.3556679	total: 1.03s	remaining: 275ms
# 79:	learn: 0.3552383	total: 1.05s	remaining: 262ms
# 80:	learn: 0.3547605	total: 1.06s	remaining: 249ms
# 81:	learn: 0.3542521	total: 1.07s	remaining: 236ms
# 82:	learn: 0.3537436	total: 1.09s	remaining: 223ms
# 83:	learn: 0.3532234	total: 1.1s	remaining: 210ms
# 84:	learn: 0.3528277	total: 1.11s	remaining: 197ms
# 85:	learn: 0.3521874	total: 1.13s	remaining: 184ms
# 86:	learn: 0.3517964	total: 1.14s	remaining: 171ms
# 87:	learn: 0.3513544	total: 1.15s	remaining: 157ms
# 88:	learn: 0.3508984	total: 1.17s	remaining: 145ms
# 89:	learn: 0.3503978	total: 1.18s	remaining: 132ms
# 90:	learn: 0.3499157	total: 1.2s	remaining: 118ms
# 91:	learn: 0.3494237	total: 1.21s	remaining: 105ms
# 92:	learn: 0.3489043	total: 1.23s	remaining: 92.3ms
# 93:	learn: 0.3484664	total: 1.24s	remaining: 79.1ms
# 94:	learn: 0.3480478	total: 1.25s	remaining: 65.8ms
# 95:	learn: 0.3476859	total: 1.26s	remaining: 52.7ms
# 96:	learn: 0.3473177	total: 1.28s	remaining: 39.6ms
# 97:	learn: 0.3469044	total: 1.29s	remaining: 26.4ms
# 98:	learn: 0.3465469	total: 1.31s	remaining: 13.2ms
# 99:	learn: 0.3461167	total: 1.32s	remaining: 0us
# Learning rate set to 0.47469
# 0:	learn: 0.5580566	total: 14.2ms	remaining: 1.4s
# 1:	learn: 0.5162546	total: 27.2ms	remaining: 1.33s
# 2:	learn: 0.4993501	total: 38.7ms	remaining: 1.25s
# 3:	learn: 0.4863152	total: 51.2ms	remaining: 1.23s
# 4:	learn: 0.4748169	total: 63.7ms	remaining: 1.21s
# 5:	learn: 0.4652014	total: 76.5ms	remaining: 1.2s
# 6:	learn: 0.4578807	total: 89.5ms	remaining: 1.19s
# 7:	learn: 0.4532094	total: 102ms	remaining: 1.17s
# 8:	learn: 0.4475100	total: 114ms	remaining: 1.15s
# 9:	learn: 0.4430933	total: 128ms	remaining: 1.15s
# 10:	learn: 0.4394084	total: 139ms	remaining: 1.13s
# 11:	learn: 0.4348377	total: 154ms	remaining: 1.13s
# 12:	learn: 0.4317669	total: 168ms	remaining: 1.12s
# 13:	learn: 0.4295894	total: 181ms	remaining: 1.11s
# 14:	learn: 0.4271994	total: 192ms	remaining: 1.09s
# 15:	learn: 0.4245471	total: 207ms	remaining: 1.08s
# 16:	learn: 0.4219604	total: 221ms	remaining: 1.08s
# 17:	learn: 0.4200853	total: 234ms	remaining: 1.06s
# 18:	learn: 0.4172277	total: 245ms	remaining: 1.04s
# 19:	learn: 0.4156444	total: 256ms	remaining: 1.02s
# 20:	learn: 0.4135486	total: 270ms	remaining: 1.01s
# 21:	learn: 0.4114133	total: 282ms	remaining: 1s
# 22:	learn: 0.4090640	total: 294ms	remaining: 986ms
# 23:	learn: 0.4067701	total: 306ms	remaining: 970ms
# 24:	learn: 0.4044240	total: 320ms	remaining: 960ms
# 25:	learn: 0.4025322	total: 332ms	remaining: 944ms
# 26:	learn: 0.4011738	total: 343ms	remaining: 928ms
# 27:	learn: 0.3995628	total: 355ms	remaining: 912ms
# 28:	learn: 0.3980922	total: 368ms	remaining: 902ms
# 29:	learn: 0.3971353	total: 380ms	remaining: 888ms
# 30:	learn: 0.3956607	total: 394ms	remaining: 877ms
# 31:	learn: 0.3942476	total: 408ms	remaining: 867ms
# 32:	learn: 0.3925964	total: 423ms	remaining: 859ms
# 33:	learn: 0.3911231	total: 437ms	remaining: 849ms
# 34:	learn: 0.3893825	total: 452ms	remaining: 839ms
# 35:	learn: 0.3883060	total: 466ms	remaining: 828ms
# 36:	learn: 0.3865384	total: 481ms	remaining: 818ms
# 37:	learn: 0.3852117	total: 492ms	remaining: 803ms
# 38:	learn: 0.3839865	total: 504ms	remaining: 789ms
# 39:	learn: 0.3828237	total: 517ms	remaining: 775ms
# 40:	learn: 0.3816943	total: 531ms	remaining: 763ms
# 41:	learn: 0.3809705	total: 544ms	remaining: 752ms
# 42:	learn: 0.3797785	total: 557ms	remaining: 738ms
# 43:	learn: 0.3788070	total: 568ms	remaining: 723ms
# 44:	learn: 0.3779919	total: 582ms	remaining: 711ms
# 45:	learn: 0.3772251	total: 594ms	remaining: 697ms
# 46:	learn: 0.3763814	total: 606ms	remaining: 684ms
# 47:	learn: 0.3754455	total: 618ms	remaining: 669ms
# 48:	learn: 0.3746952	total: 632ms	remaining: 658ms
# 49:	learn: 0.3738126	total: 647ms	remaining: 647ms
# 50:	learn: 0.3730794	total: 661ms	remaining: 635ms
# 51:	learn: 0.3721742	total: 673ms	remaining: 622ms
# 52:	learn: 0.3713241	total: 686ms	remaining: 608ms
# 53:	learn: 0.3706325	total: 699ms	remaining: 595ms
# 54:	learn: 0.3698790	total: 711ms	remaining: 582ms
# 55:	learn: 0.3690889	total: 725ms	remaining: 570ms
# 56:	learn: 0.3682871	total: 737ms	remaining: 556ms
# 57:	learn: 0.3674325	total: 750ms	remaining: 543ms
# 58:	learn: 0.3667071	total: 762ms	remaining: 529ms
# 59:	learn: 0.3660467	total: 774ms	remaining: 516ms
# 60:	learn: 0.3654953	total: 785ms	remaining: 502ms
# 61:	learn: 0.3649104	total: 798ms	remaining: 489ms
# 62:	learn: 0.3641742	total: 813ms	remaining: 477ms
# 63:	learn: 0.3634022	total: 825ms	remaining: 464ms
# 64:	learn: 0.3628808	total: 839ms	remaining: 452ms
# 65:	learn: 0.3623886	total: 852ms	remaining: 439ms
# 66:	learn: 0.3618823	total: 867ms	remaining: 427ms
# 67:	learn: 0.3614114	total: 882ms	remaining: 415ms
# 68:	learn: 0.3605963	total: 895ms	remaining: 402ms
# 69:	learn: 0.3600988	total: 909ms	remaining: 390ms
# 70:	learn: 0.3596423	total: 921ms	remaining: 376ms
# 71:	learn: 0.3591155	total: 934ms	remaining: 363ms
# 72:	learn: 0.3587145	total: 947ms	remaining: 350ms
# 73:	learn: 0.3583223	total: 959ms	remaining: 337ms
# 74:	learn: 0.3579319	total: 971ms	remaining: 324ms
# 75:	learn: 0.3573079	total: 983ms	remaining: 310ms
# 76:	learn: 0.3566910	total: 997ms	remaining: 298ms
# 77:	learn: 0.3561684	total: 1.01s	remaining: 285ms
# 78:	learn: 0.3556679	total: 1.02s	remaining: 272ms
# 79:	learn: 0.3552383	total: 1.03s	remaining: 259ms
# 80:	learn: 0.3547605	total: 1.05s	remaining: 246ms
# 81:	learn: 0.3542521	total: 1.06s	remaining: 233ms
# 82:	learn: 0.3537436	total: 1.07s	remaining: 220ms
# 83:	learn: 0.3532234	total: 1.09s	remaining: 207ms
# 84:	learn: 0.3528277	total: 1.1s	remaining: 194ms
# 85:	learn: 0.3521874	total: 1.11s	remaining: 181ms
# 86:	learn: 0.3517964	total: 1.13s	remaining: 168ms
# 87:	learn: 0.3513544	total: 1.14s	remaining: 155ms
# 88:	learn: 0.3508984	total: 1.15s	remaining: 143ms
# 89:	learn: 0.3503978	total: 1.17s	remaining: 130ms
# 90:	learn: 0.3499157	total: 1.18s	remaining: 117ms
# 91:	learn: 0.3494237	total: 1.19s	remaining: 104ms
# 92:	learn: 0.3489043	total: 1.21s	remaining: 91ms
# 93:	learn: 0.3484664	total: 1.22s	remaining: 77.9ms
# 94:	learn: 0.3480478	total: 1.23s	remaining: 64.9ms
# 95:	learn: 0.3476859	total: 1.24s	remaining: 51.9ms
# 96:	learn: 0.3473177	total: 1.26s	remaining: 38.9ms
# 100%|██████████| 1/1 [00:16<00:00, 16.59s/it]
# 100%|██████████| 2/2 [00:39<00:00, 19.51s/it]
# 97:	learn: 0.3469044	total: 1.27s	remaining: 25.9ms
# 98:	learn: 0.3465469	total: 1.29s	remaining: 13ms
# 99:	learn: 0.3461167	total: 1.3s	remaining: 0us
#                        dataset  \
# 0  rolling_Intervals_12Stats_0
# 1                         Test
#
#                                                model     score
# 0  (CatBoost, trained_CatBoost_on_rolling_Interva...  0.759304
# 1           (CatBoost, trained_CatBoost_on_Test.pkl)  0.759247
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 nagivation = MainNavigation()
#       2 # nagivation.create_dataset()
# ----> 3 nagivation.run_model_selection()
#       4 nagivation.get_submission()
#
# Cell In[1], line 100, in MainNavigation.run_model_selection(self)
#      98 print(results)
#      99 results = results.sort_values(by='score')
# --> 100 self.trained_model_name = model_selector.final_model_fit_save(results.iloc[0,:0])
#     101 return results
#
# File c:\Users\budar\Jupiter notebooks\VK_test_task\my_models_pipline.py:91, in ModelsPipline.final_model_fit_save(self, name_data)
#      89 model = self.best_model
#      90 model.set_params(**self.best_model_params)
# ---> 91 X_train, y_train = self.load_train_test_data(name_data, train_flag= False)
#      92 model.fit(X_train, y_train)
#      93 trained_model_name = f'trained_BestModel_catboost_on_{name_data}.pkl'
#
# File c:\Users\budar\Jupiter notebooks\VK_test_task\my_models_pipline.py:24, in ModelsPipline.load_train_test_data(self, name, test_size, train_flag)
#      20 ''' Выгружаю датасет по name из self.dataframes_path,
#      21     если такого нет - выгружаю дефолтный (выберу какой) '''
#      23 default_dataset = 'intervals_rolling_dataframe.csv'
# ---> 24 print(self.dataframes_path.get(name, default_dataset))
#      25 data = pd.read_csv(self.dataframes_path.get(name, default_dataset), index_col= False)
#      26 if not train_flag:
#
# TypeError: unhashable type: 'Series'
